# %% [markdown]
# <a href="https://colab.research.google.com/github/AIClubRGB/Schafkopf_bot/blob/master/Schafkopf_bot_how_to_train_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test for GPU-availability

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# Found GPU at: /device:GPU:0
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5461821159273759237, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3697581706460295577
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 4209737865145082237
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14800692839
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8980487899042445190
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %% [markdown]
# # Installation of CUDA 8.0 on UBuntu 16.04

# %%
# %cd ~
# !ls

# %% [markdown]
# ## Installation of gcc, cmake, make

# %%
# !apt-get update
# !apt-get upgrade
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# !apt-get install libavcodec-dev libavformat-dev libswscale-d

# %%
# !apt-get -y install cmake
# !which cmake

# !cmake --version

# !apt-get install libopencv-dev

# !apt install g++-5

# !apt install gcc-5

# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 10
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 20
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 10
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 20

# !update-alternatives --install /usr/bin/cc cc /usr/bin/gcc 30
# !update-alternatives --set cc /usr/bin/gcc
# !update-alternatives --install /usr/bin/c++ c++ /usr/bin/g++ 30
# !update-alternatives --set c++ /usr/bin/g++

# %% [markdown]
# ## Installation of Cuda

# %%
# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !apt-get update -qq

#Here were are installing compilers and creating some links
# !apt-get install cuda -y -qq #gcc-5 g++-5 
#!ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
#!ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# !apt update
# !apt upgrade
# !apt install cuda-8.0 -y

# %%
#Now let's see whether the GPU is here and CUDA was successfully installed!
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("'sup!'")

# !/usr/local/cuda/bin/nvcc --version

# %% [markdown]
# # Setup Yolo/darknet from AlexeyAB

# %%
# !git clone https://github.com/AlexeyAB/darknet/
  
#!apt-get install vim

# %%
# !ls
# %cd darknet


#!vim Makefile

# %%
# !ls
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# !wget https://pjreddie.com/media/files/darknet53.conv.74

# %%
# !ls
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile

# %%
#!vim Makefile

# %%
# !ls
# %cd ../
# !ls

# %%
# %cd ~/darknet
# !make

# %%
# !ls
#Now, let's see if everything works by running it on a test image
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
#!./darknet detect cfg/yolov3-tiny_obj.cfg yolov3-tiny.weights data/person.jpg
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
imShow('predictions.jpg')

# %%
#imShow('predictions.jpg')

# %%
#imShow('predictions.jpg')

# %% [markdown]
# # Setup Schafkopf_bot from AIClubRGB

# %%
# %cd ~/darknet/data
# !mkdir obj
# !ls
# %cd obj

# %%
#%cd obj
#%cd .. 
#!rm -r obj
#!ls
# !git clone https://github.com/AIClubRGB/Schafkopf_bot.git

# %%
# %cd Schafkopf_bot
# !mv * ../
# %cd ..
# !rm -r Schafkopf_bot
# !ls

# %%
# !python convcx.py
# %cd for_darknet_dir
# !mv * ../../..
# %cd ../../..
# !ls
# %cd data/obj/for_data_dir
# !mv * ../..
# %cd ../..
# !ls
# %cd obj
# !ls

# %%
# !ls
# !mv train0.txt ..
# !mv val0.txt ..
# %cd ..
# !ls
# %cd obj
# !rm -r for_darknet_dir  for_data_dir  
# !ls

# %%
# !ls
# %cd ..
# !ls

# %%
# %cd ..
# !ls

# %%
#!./darknet partial yolov3-tiny-obj.cfg yolov3-tiny.weights yolov3-tiny.conv.15 15
#!./darknet partial yolov3-tiny-obj.cfg yolov3-tiny-obj_1000.weights yolov3-tiny.conv.15 15

# %%
# %cd ~/darknet/data/
# !ls
# Out:
# /root/darknet/data
# 9k.tree     eagle.jpg	 imagenet.labels.list	   obj.data	     scream.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.names	     voc.names
# coco.names  goal.txt	 labels			   openimages.names
# dog.jpg     horses.jpg	 obj			   person.jpg

# %%
# !sed -i 's/train.txt/train0.txt/g' obj.data
# !sed -i 's/val.txt/val0.txt/g' obj.data
# !cat obj.data

# %% [markdown]
# ## Training

# %%
# %cd ~/darknet
#%cd data/obj
#!mv train0.txt ..
#!mv val0.txt ..
#!cd ..
#!cat data/train0.txt
# Out:
# /root/darknet

# %%
# !./darknet detector train data/obj.data yolo-obj.cfg darknet53.conv.74 -dont_show
# Out:
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000023, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000030, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.562719, Class: 0.087238, Obj: 0.393741, No Obj: 0.000263, .5R: 0.733333, .75R: 0.000000,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000022, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.580929, Class: 0.045185, Obj: 0.168025, No Obj: 0.000100, .5R: 0.500000, .75R: 0.000000,  count: 2
# Region 106 Avg IOU: 0.500101, Class: 0.053236, Obj: 0.482145, No Obj: 0.000235, .5R: 0.400000, .75R: 0.100000,  count: 10
#
#  999: 3.145922, 3.184047 avg loss, 0.000996 rate, 18.582951 seconds, 63936 images
# Loaded: 0.000043 seconds
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000021, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0
.5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.647822, Class: 0.052210, Obj: 0.412564, No Obj: 0.000235, .5R: 0.933333, .75R: 0.133333,  count: 15
#
#  1001: 2.865876, 3.114384 avg loss, 0.001000 rate, 15.328470 seconds, 64064 images
# Loaded: 0.000034 seconds
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000020, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.370098, Class: 0.036948, Obj: 0.070493, No Obj: 0.000103, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: 0.729237, Class: 0.047786, Obj: 0.531404, No Obj: 0.000487, .5R: 0.923077, .75R: 0.307692,  count: 13
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000020, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000255, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.731030, Class: 0.067516, Obj: 0.610698, No Obj: 0.000452, .5R: 0.933333, .75R: 0.466667,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000020, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000073, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.634572, Class: 0.050491, Obj: 0.515958, No Obj: 0.000404, .5R: 0.750000, .75R: 0.250000,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000019, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.488720, Class: 0.039588, Obj: 0.270031, No Obj: 0.000532, .5R: 0.400000, .75R: 0.000000,  count: 5
# Region 106 Avg IOU: 0.674137, Class: 0.055700, Obj: 0.523592, No Obj: 0.000207, .5R: 1.000000, .75R: 0.000000,  count: 6
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000024, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000092, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.690136, Class: 0.087895, Obj: 0.598670, No Obj: 0.000446, .5R: 0.866667, .75R: 0.266667,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000018, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.384944, Class: 0.063379, Obj: 0.067076, No Obj: 0.000190, .5R: 0.000000, .75R: 0.000000,  count: 3
# Region 106 Avg IOU: 0.671380, Class: 0.089569, Obj: 0.297933, No Obj: 0.000282, .5R: 1.000000, .75R: 0.125000,  count: 8
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000020, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000029, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.679323, Class: 0.078753, Obj: 0.544989, No Obj: 0.000449, .5R: 0.933333, .75R: 0.200000,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000018, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000124, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.715105, Class: 0.051222, Obj: 0.433383, No Obj: 0.000417, .5R: 1.000000, .75R: 0.333333,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000019, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.263300, Class: 0.024575, Obj: 0.302826, No Obj: 0.000169, .5R: 0.000000, .75R: 0.000000,  count: 2
# Region 106 Avg IOU: 0.682855, Class: 0.053507, Obj: 0.501057, No Obj: 0.000373, .5R: 0.916667, .75R: 0.500000,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000021, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.408699, Class: 0.038603, Obj: 0.303670, No Obj: 0.000570, .5R: 0.000000, .75R: 0.000000,  count: 3
# Region 106 Avg IOU: 0.689460, Class: 0.064933, Obj: 0.640723, No Obj: 0.000338, .5R: 0.888889, .75R: 0.333333,  count: 9
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000020, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000092, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.711453, Class: 0.050223, Obj: 0.630573, No Obj: 0.000413, .5R: 1.000000, .75R: 0.333333,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000020, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.565541, Class: 0.047682, Obj: 0.571980, No Obj: 0.000318, .5R: 0.666667, .75R: 0.000000,  count: 3
# Region 106 Avg IOU: 0.676209, Class: 0.045330, Obj: 0.367166, No Obj: 0.000286, .5R: 0.909091, .75R: 0.363636,  count: 11
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000018, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.415132, Class: 0.032314, Obj: 0.420658, No Obj: 0.000828, .5R: 0.250000, .75R: 0.000000,  count: 8
# Region 106 Avg IOU: 0.643429, Class: 0.073769, Obj: 0.326040, No Obj: 0.000258, .5R: 0.857143, .75R: 0.142857,  count: 7
# ^C

# %%
#!./darknet detector train data/obj.data yolov3-tiny-obj.cfg yolov3-tiny.conv.15 -dont_show
#!./darknet detector train data/obj.data yolov3-tiny-obj.cfg yolov3-tiny-obj_2000_tr2.weights -dont_show


#!./darknet detector train data/obj.data yolo-obj.cfg yolo-obj_2000.weights -dont_show 
#!cp backup/yolo-obj_3000.weights yolo-obj_3000.weights
#!./darknet detector train data/obj.data yolo-obj.cfg yolo-obj_3000.weights -dont_show

# %% [markdown]
# ## change learn_rate for fine tuning after stagnation of IOU at about 3000 iterations

# %%
# %cd ~/darknet/
# !cat yolo-obj.cfg
# !sed -i 's/learning_rate=0.001/learning_rate=0.0001/g' yolo-obj.cfg
# !cat yolo-obj.cfg

# %%
# !ls
# %cd backup
# !ls

# %% [markdown]
# # For retraining: loading and saving models from google drive

# %% [markdown]
# # Setup drive tools

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ## Save model

# %%
# %cd ~/darknet/backup/
# !ls
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a file.
uploaded = drive.CreateFile({'title': 'yolo-obj_0_1000.weights'})
uploaded.SetContentFile('yolo-obj_1000.weights')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))

# %% [markdown]
# ## Load model from drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#file_id = 'https://drive.google.com/open?id=1FSxixz9iJEvVQdVMCLTHEFaozCNOqcmX' # URL id. 

#downloaded = drive.CreateFile({'id': file_id})
#downloaded.GetContentFile('yolo-obj_2000.weights')

# %cd ~/darknet
# !ls /content/gdrive/'My Drive'
# !cp /content/gdrive/'My Drive'/yolo-obj_0_1000.weights ~/darknet
# !ls

# %% [markdown]
# # Retraining

# %%
# %cd ~/darknet/
# !ls
# !mv yolo-obj_0_1000.weights yolo-obj_1000.weights
# !ls

# %%
# !./darknet detector train data/obj.data yolo-obj.cfg yolo-obj_1000.weights -dont_show
# Out:
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000007, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.678656, Class: 0.177847, Obj: 0.674904, No Obj: 0.000686, .5R: 0.866667, .75R: 0.333333,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000021, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.723613, Class: 0.270712, Obj: 0.444586, No Obj: 0.000547, .5R: 0.916667, .75R: 0.500000,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.738582, Class: 0.092708, Obj: 0.318981, No Obj: 0.000303, .5R: 1.000000, .75R: 0.500000,  count: 4
# Region 106 Avg IOU: 0.665242, Class: 0.167429, Obj: 0.512665, No Obj: 0.000708, .5R: 0.833333, .75R: 0.250000,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000011, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.696270, Class: 0.198964, Obj: 0.616722, No Obj: 0.000830, .5R: 0.866667, .75R: 0.266667,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000007, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.743750, Class: 0.266591, Obj: 0.340128, No Obj: 0.000761, .5R: 1.000000, .75R: 0.400000,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000007, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.658466, Class: 0.242647, Obj: 0.535752, No Obj: 0.000746, .5R: 0.928571, .75R: 0.285714,  count: 14
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000041, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.765929, Class: 0.246891, Obj: 0.523367, No Obj: 0.000813, .5R: 1.000000, .75R: 0.625000,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000035, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.705780, Class: 0.293350, Obj: 0.543333, No Obj: 0.000683, .5R: 1.000000, .75R: 0.307692,  count: 13
#
#  1999: 2.016384, 1.978367 avg loss, 0.000100 rate, 7.914278 seconds, 127936 images
# Loaded: 0.000033 seconds
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.688222, Class: 0.144939, Obj: 0.579633, No Obj: 0.000769, .5R: 0.875000, .75R: 0.437500,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000007, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.704638, Class: 0.082077, Obj: 0.676768, No Obj: 0.000876, .5R: 1.000000, .75R: 0.250000,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000037, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.695272, Class: 0.297164, Obj: 0.598016, No Obj: 0.000678, .5R: 0.928571, .75R: 0.428571,  count: 14
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.764726, Class: 0.201522, Obj: 0.632887, No Obj: 0.000695, .5R: 1.000000, .75R: 0.416667,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000067, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.730575, Class: 0.349683, Obj: 0.654108, No Obj: 0.000794, .5R: 1.000000, .75R: 0.416667,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000007, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.648106, Class: 0.101358, Obj: 0.652892, No Obj: 0.000657, .5R: 0.866667, .75R: 0.266667,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000008, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.726822, Class: 0.178285, Obj: 0.611281, No Obj: 0.000792, .5R: 0.916667, .75R: 0.500000,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000007, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0
seconds
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000018, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.772950, Class: 0.272619, Obj: 0.789093, No Obj: 0.000553, .5R: 1.000000, .75R: 0.600000,  count: 10
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000111, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.743043, Class: 0.322463, Obj: 0.669360, No Obj: 0.000673, .5R: 1.000000, .75R: 0.384615,  count: 13
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000010, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.731351, Class: 0.242817, Obj: 0.547018, No Obj: 0.000719, .5R: 1.000000, .75R: 0.437500,  count: 16
# ^C

# %% [markdown]
# ## save retrained model

# %%
# %cd ~/darknet/backup/
# !ls
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a file.
uploaded = drive.CreateFile({'title': 'yolo-obj_0_2000.weights'})
uploaded.SetContentFile('yolo-obj_2000.weights')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# /root/darknet/backup
# yolo-obj_2000.weights  yolo-obj_last.weights
# Uploaded file with ID 1_K9TGWUuAmIGhmTgcRfqPsRBtVwZPGwP

# %% [markdown]
# ## retraining 2

# %%
# %cd ~/darknet/backup/
# !mv yolo-obj_last.weights ..
# %cd ~/darknet/
# !ls
# Out:
# /root/darknet/backup
# /root/darknet
# 3rdparty	    DarknetConfig.cmake.in  README.md
# appveyor.yml	    darknet.py		    results
# backup		    darknet_video.py	    scripts
# build		    data		    src
# build.ps1	    image_yolov2.sh	    video_v2.sh
# build.sh	    image_yolov3.sh	    video_yolov3.sh
# cfg		    include		    yolo-obj_2000.weights
# chart.png	    json_mjpeg_streams.sh   yolo-obj.cfg
# cmake		    LICENSE		    yolo-obj_last.weights
# CMakeLists.txt	    Makefile		    yolov3-tiny.weights
# CMakeSettings.json  net_cam_v3.sh	    yolov3.weights
# darknet		    obj
# darknet53.conv.74   predictions.jpg

# %%
# !ls backup
# Out:
# yolo-obj_last.weights

# %%
# !./darknet detector train data/obj.data yolo-obj.cfg yolo-obj_last.weights -dont_show
# Out:
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000011, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.708948, Class: 0.374003, Obj: 0.495492, No Obj: 0.000570, .5R: 1.000000, .75R: 0.375000,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000010, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000135, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.662591, Class: 0.580770, Obj: 0.566312, No Obj: 0.000479, .5R: 0.916667, .75R: 0.250000,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000187, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.736747, Class: 0.658758, Obj: 0.548158, No Obj: 0.000516, .5R: 1.000000, .75R: 0.416667,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000010, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000007, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.721781, Class: 0.429656, Obj: 0.628183, No Obj: 0.000552, .5R: 1.000000, .75R: 0.384615,  count: 13
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000010, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000005, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.684254, Class: 0.642137, Obj: 0.437683, No Obj: 0.000489, .5R: 0.866667, .75R: 0.400000,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.618572, Class: 0.624167, Obj: 0.431894, No Obj: 0.000504, .5R: 0.846154, .75R: 0.076923,  count: 13
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000093, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.738971, Class: 0.457075, Obj: 0.544292, No Obj: 0.000569, .5R: 1.000000, .75R: 0.428571,  count: 14
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000158, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.710335, Class: 0.537842, Obj: 0.553066, No Obj: 0.000508, .5R: 0.933333, .75R: 0.533333,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000010, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.749517, Class: 0.733212, Obj: 0.558916, No Obj: 0.000656, .5R: 0.937500, .75R: 0.625000,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.737333, Class: 0.018997, Obj: 0.211421, No Obj: 0.000261, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: 0.650020, Class: 0.530732, Obj: 0.473057, No Obj: 0.000539, .5R: 1.000000, .75R: 0.000000,  count: 13
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000010, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000005, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.703684, Class: 0.512320, Obj: 0.653029, No Obj: 0.000569, .5R: 0.923077, .75R: 0.307692,  count: 13
#
#  2942: 1.602434, 1.492051 avg loss, 0.000100 rate, 9.409850 seconds, 188288 images
# Loaded: 0.000031 seconds
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.795022, Class: 0.011791, Obj: 0.875536, No Obj: 0.000151, .5R: 1.000000, .75R: 1.000000,  count: 1
# Region 106 Avg IOU: 0.623497, Class: 0.436332, Obj: 0.385817, No Obj: 0.000468, .5R: 0.916667, .75R: 0.166667,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000102, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.739743, Class: 0.538145, Obj: 0.755454, No Obj: 0.000603, .5R: 1.000000, .75R: 0.428571,  count: 14
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.656150, Class: 0.456463, Obj: 0.414165, No Obj: 0.000479, .5R: 0.916667, .75R: 0.333333,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.518435, Class: 0.050683, Obj: 0.029451, No Obj: 0.000307, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: 0.765027, Class: 0.514371, Obj: 0.620578, No Obj: 0.000560, .5R: 1.000000, .75R: 0.583333,  count: 12
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.719183, Class: 0.633494, Obj: 0.538079, No Obj: 0.000652, .5R: 1.000000, .75R: 0.266667,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.748064, Class: 0.689912, Obj: 0.559804, No Obj: 0.000557, .5R: 1.000000, .75R: 0.384615,  count: 13
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000010, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.714190, Class: 0.462159, Obj: 0.578610, No Obj: 0.000645, .5R: 0.933333, .75R: 0.333333,  count: 15
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000009, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000071, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.733496, Class: 0.522569, Obj: 0.605077, No Obj: 0.000656, .5R: 0.933333, .75R: 0.533333,  count: 15
# ^C

# %%
# %cd ~/darknet/backup/
# !ls
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a file.
uploaded = drive.CreateFile({'title': 'yolo-obj_0_2900.weights'})
uploaded.SetContentFile('yolo-obj_last.weights')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# /root/darknet/backup
# yolo-obj_last.weights
# Uploaded file with ID 1GTvNP1wC-rP8mrTEQZudedvq87GsYIJn

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#file_id = 'https://drive.google.com/open?id=1FSxixz9iJEvVQdVMCLTHEFaozCNOqcmX' # URL id. 

#downloaded = drive.CreateFile({'id': file_id})
#downloaded.GetContentFile('yolo-obj_2000.weights')

# %cd ~/darknet
# !ls /content/gdrive/'My Drive'
# !cp /content/gdrive/'My Drive'/yolo-obj_0_2900.weights ~/darknet
# !ls

# %%
# !mv yolo-obj_0_2900.weights yolo-obj_last.weights

# %%
# !./darknet detector train data/obj.data yolo-obj.cfg yolo-obj_last.weights -dont_show

# %% [markdown]
# # Test

# %%
# %cd ~/darknet/
# !ls
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)
# Out:
# /root/darknet
# 3rdparty	    DarknetConfig.cmake.in  README.md
# appveyor.yml	    darknet.py		    results
# backup		    darknet_video.py	    scripts
# build		    data		    src
# build.ps1	    image_yolov2.sh	    video_v2.sh
# build.sh	    image_yolov3.sh	    video_yolov3.sh
# cfg		    include		    yolo-obj_1000.weights
# chart.png	    json_mjpeg_streams.sh   yolo-obj_2000.weights
# cmake		    LICENSE		    yolo-obj.cfg
# CMakeLists.txt	    Makefile		    yolov3-tiny.weights
# CMakeSettings.json  net_cam_v3.sh	    yolov3.weights
# darknet		    obj
# darknet53.conv.74   predictions.jpg

# %%
# %cd ~/darknet
#!./darknet detect yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_last.weights data/obj/train/003110976.jpg
#darknet.exe detector test data/obj.data yolo-obj.cfg yolo-obj_8000.weights
#!./darknet detector test data/obj.data ../yolov3-tiny-obj_test.cfg yolov3-tiny-obj_2000_tr2.weights data/obj/train/003110976.jpg 




#!./darknet detector test data/obj.data yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_1000.weights data/obj/train/003110976.jpg
#!./darknet detector test data/obj.data yolo-obj.cfg yolo-obj_0_1000.weights data/obj/train0/000007269.jpg
# !./darknet detector test data/obj.data yolo-obj.cfg backup/yolo-obj_last.weights data/obj/train0/000007269.jpg





'''
# !./darknet detector test data/obj.data ../yolov3-tiny-obj_test.cfg yolov3-tiny-obj_2000_tr2.weights data/obj/train/003110976.jpg 
# !./darknet detector test data/obj.data ../yolov3-tiny-obj_test.cfg yolov3-tiny.weights data/obj/train/003110976.jpg 

#!./darknet detector recall data/obj.data data/obj.data ../yolov3-tiny-obj_test.cfg yolov3-tiny-obj_2000_tr2.weights
#!./darknet detect yolov3-tiny-obj.cfg yolov3-tiny.weights data/obj/train/003110976.jpg

#!./darknet detect yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_last.weights 000600862.jpg	
'''
# Out:
# /root/darknet
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
#   13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   17 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   20 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   23 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   26 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   29 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   32 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   35 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    52 x  52 x 256   ->    26 x  26 x 512 1.595 BF
#   38 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   39 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   42 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   45 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   48 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   51 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   54 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   57 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   60 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    26 x  26 x 512   ->    13 x  13 x1024 1.595 BF
#   63 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   64 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   67 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   70 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   73 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   76 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   77 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   78 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   79 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   80 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   81 conv    111  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 111 0.038 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256 0.044 BF
#   85 upsample            2x    13 x  13 x 256   ->    26 x  26 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256 0.266 BF
#   88 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   89 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   90 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   91 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   92 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   93 conv    111  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 111 0.077 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128 0.044 BF
#   97 upsample            2x    26 x  26 x 128   ->    52 x  52 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128 0.266 BF
#  100 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  101 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  102 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  103 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  104 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  105 conv    111  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 111 0.154 BF
#  106 yolo
# Total BFLOPS 65.515
#  Allocate additional workspace_size = 49.84 MB
# Loading weights from backup/yolo-obj_last.weights...
#  seen 64
# Done!
# data/obj/train0/000007269.jpg: Predicted in 1112.957000 milli-seconds.
# GA: 33%
# GA: 48%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:16897): Gtk-WARNING **: 17:53:08.950: cannot open display:
# '\n!./darknet detector test data/obj.data ../yolov3-tiny-obj_test.cfg yolov3-tiny-obj_2000_tr2.weights data/obj/train/003110976.jpg \n!./darknet detector test data/obj.data ../yolov3-tiny-obj_test.cfg yolov3-tiny.weights data/obj/train/003110976.jpg \n\n#!./darknet detector recall data/obj.data data/obj.data ../yolov3-tiny-obj_test.cfg yolov3-tiny-obj_2000_tr2.weights\n#!./darknet detect yolov3-tiny-obj.cfg yolov3-tiny.weights data/obj/train/003110976.jpg\n\n#!./darknet detect yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_last.weights 000600862.jpg\t\n'

# %%
# !ls
# %cd ..

# %%
# !ls 
# %cd ~/darknet
# Out:
# yolo-obj_1000.weights  yolo-obj_last.weights  yolov3-tiny-obj_last.weights
# /root/darknet

# %%
imShow('data/obj/train0/000007269.jpg')
#%cd ../../..
# !ls

# %%
imShow('predictions.jpg')

# %%
# !./darknet detector recall data/obj.data yolo-obj.cfg yolo-obj_0_1000.weights

# %%
def download(path):
  from google.colab import files
  files.download(path)

# %%
download('predictions.jpg')

# %%
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# %%
upload()
# Out:
#      <input type="file" id="files-74d24ada-bc1d-4498-9c3f-80a4dc2c3cba" name="files[]" multiple disabled />
#      <output id="result-74d24ada-bc1d-4498-9c3f-80a4dc2c3cba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 000139850.jpg to 000139850.jpg
# saved file 000139850.jpg

# %%
# !./darknet detect yolov3-tiny-obj_test.cfg backup/yolov3-tiny-obj_2000.weights data/obj/train/003110976.jpg -thresh 10

# %%
imShow('predictions.jpg')

# %%
# !./darknet detector train data/obj.data yolo-obj.cfg darknet53.conv.74 -dont_show

# %%
# !ls

# %%
# !cat
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# %cd data
# Out:
# /content/sample_data/darknet/data

# %%
download('train.txt')

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Requirement already satisfied: gputil in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Gen RAM Free: 12.5 GB  | Proc size: 788.1 MB
# GPU RAM Free: 11320MB | Used: 121MB | Util   1% | Total 11441MB

# %%
print(gpu)
# Out:
# <GPUtil.GPUtil.GPU object at 0x7f53fc385978>
